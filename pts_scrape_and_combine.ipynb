# %%
import pandas as pd
import os
from bs4 import BeautifulSoup
import requests
import numpy as np
import time
import random

# %%
def scrape_gamelog(player_id, url, year):
    
    #Go to website and open basketball reference page
    response = requests.get(url)

    # Check for response status
    if response.status_code != 200:
        print(f"Failed to retrieve data for {player_id}. Status code: {response.status_code}")
        return None  # Exit function early
    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.find('table', {'id': 'pgl_basic'})
    headers = [th.text for th in table.find('thead').find_all('th')][1:]
    rows = table.find('tbody').find_all('tr')
    data = []
    # Pull the data from the table
    for row in rows:
        if row.find('th', {'scope': 'row'}) is not None:
            game_date = row.find('th').text
            cells = row.find_all('td')
            cells_data = [cell.text for cell in cells]
            data.append([player_id, game_date] + cells_data)
    headers = ['Player_ID', 'Date'] + headers
    df = pd.DataFrame(data, columns=headers)
    # Remove rows where the player did not play (G column is empty)
    df = df[df['G'] != '']
    # Modify the 7th column based on its content
    df.iloc[:, 6] = df.iloc[:, 6].apply(lambda x: 'away' if '@' in x else 'home')
    # Rename columns
    df.rename(columns={df.columns[8]: 'Court'}, inplace=True)
    # Remove the second column
    df.drop(df.columns[1], axis=1, inplace=True)
    # Define the directory where you want to save the file
    save_directory = f"C:\\Github_Repos\MATH2015-Linear-Regression-Model\\Linear Regression Data\\Game Logs"
    # Ensure the directory exists
    os.makedirs(save_directory, exist_ok=True)
    # Create the full file path
    file_name = os.path.join(save_directory, f'{player_id}_gamelog_{year}.xlsx')
    # Save to Excel with player ID in the file name
    with pd.ExcelWriter(file_name) as writer:
        df.to_excel(writer, index=False, sheet_name='Game Log')

# %%
def scrape_list_names(players_path):
    player_data = pd.read_csv(players_path)
    filtered_players = player_data[player_data["MP"] > 8]
    player_list = filtered_players['Player-additional'].tolist()
    return player_list

# %%
#opponent_shooting_header_str = (
#'Rk\tTeam\tG\tMP\tFG%\tDist.\t \t2P\tRange_0-3\tRange_3-10\tRange_10-16\tRange_16-3P\t3P\t \t2P\tRange_0-3_Made\tRange_3-10_Made\tRange_10-16_Made\tRange_16-3P_Made\t3P_Made\t \t2P_Made\t3P_Made\t '
#    '\t%FGA\tMd.\t \t%FGA_Made\tMd_Made\t \t%3PA\t3P%')



def update_header(csv_path, header_string):
    """
    Updates the header of the opponent shooting CSV file with the provided header string.

    Args:
        csv_path (str): Path to the opponent shooting CSV file.
        header_string (str): Tab-separated string of column names.
    """
    # Convert the string to a list of headers
    new_header = [col.strip() for col in header_string.split('\t')]

    # Read the CSV without a header
    try:
        data = pd.read_csv(csv_path, header=None, encoding='ISO-8859-1')
    except FileNotFoundError:
        print(f"File not found: {csv_path}")
        return
    except pd.errors.ParserError as e:
        print(f"Error parsing the CSV file: {e}")
        return

    # Assign the new header to the DataFrame
    data.columns = new_header

    # Save the updated CSV
    data.to_csv(csv_path, index=False)
    print(f"Updated CSV file saved with new header: {csv_path}")

# %% [markdown]
# ### Player Features	Location
# True Shooting %	Advanced Stats -  "TS%"
# Free throw attempt rate	Advanced Stats -  "FTr"
# Box Plus/Minus	Advanced Stats - "BPM"
# Average Points	Basic Stats - "PTS"
# Usage Rate	Advanced Stats - "USG%"
#
# ### Team Stats	Location
# Pace	Team Advanced - "Pace"
# Team Offensive Rating	Team Advanced - "ORtg"
# Opponent FG%	Opponent Team Stats - "FG%"
# Opponent Shots at Rim	Shooting Opponent - "0-3"
# Opponent Shots 3-10ft	Shooting Opponent - "3-10"
# Expected FG% (opponent)	Team Advanced = "eFG%_2"
#
# ### Other	Location
# Home/Away	Scraped Game Logs
#
# ### Output	Location
# Player Points Scored	Scraped Game Logs

# %%
abbreviation_map = {
    'Atlanta Hawks': 'ATL', 'Boston Celtics': 'BOS', 'Brooklyn Nets': 'BKN', 'Chicago Bulls': 'CHI',
    'Charlotte Hornets': 'CHA', 'Cleveland Cavaliers': 'CLE', 'Dallas Mavericks': 'DAL',
    'Denver Nuggets': 'DEN', 'Detroit Pistons': 'DET', 'Golden State Warriors': 'GSW',
    'Houston Rockets': 'HOU', 'Indiana Pacers': 'IND', 'Los Angeles Clippers': 'LAC',
    'Los Angeles Lakers': 'LAL', 'Memphis Grizzlies': 'MEM', 'Miami Heat': 'MIA',
    'Milwaukee Bucks': 'MIL', 'Minnesota Timberwolves': 'MIN', 'New Orleans Pelicans': 'NOP',
    'New York Knicks': 'NYK', 'Oklahoma City Thunder': 'OKC', 'Orlando Magic': 'ORL',
    'Philadelphia 76ers': 'PHI', 'Phoenix Suns': 'PHX', 'Portland Trail Blazers': 'POR',
    'Sacramento Kings': 'SAC', 'San Antonio Spurs': 'SAS', 'Toronto Raptors': 'TOR',
    'Utah Jazz': 'UTA', 'Washington Wizards': 'WAS'
}



def final_file_creation(fgame_log, fplayer_basic, fplayer_advanced, fteam_basic, fteam_advanced, fopponent_basic, fopponent_shooting):
    # Specify the encoding for all CSV files
    curr_player_gamelog = pd.read_excel(fgame_log)
    player_basic = pd.read_csv(fplayer_basic, encoding='ISO-8859-1')
    player_advanced = pd.read_csv(fplayer_advanced, encoding='ISO-8859-1')

    player_id = curr_player_gamelog.iloc[0]["Player_ID"]
    team_basic = pd.read_csv(fteam_basic, encoding='ISO-8859-1')
    team_basic['Team'] = team_basic['Team'].str.replace('*', '', regex=False)
    team_basic['Team'] = team_basic['Team'].replace(abbreviation_map)
    
    team_advanced = pd.read_csv(fteam_advanced, encoding='ISO-8859-1')
    team_advanced['Team'] = team_advanced['Team'].str.replace('*', '', regex=False)
    team_advanced['Team'] = team_advanced['Team'].replace(abbreviation_map)
    
    opponent_basic = pd.read_csv(fopponent_basic, encoding='ISO-8859-1')
    opponent_basic['Team'] = opponent_basic['Team'].str.replace('*', '', regex=False)
    opponent_basic['Team'] = opponent_basic['Team'].replace(abbreviation_map)
    
    opponent_shooting = pd.read_csv(fopponent_shooting, encoding='ISO-8859-1')
    opponent_shooting['Team'] = opponent_shooting['Team'].str.replace('*', '', regex=False)
    opponent_shooting['Team'] = opponent_shooting['Team'].replace(abbreviation_map)

    # Rename column if needed
    if 'Player-additional' in player_basic.columns:
        player_basic.rename(columns={'Player-additional': 'Player_ID'}, inplace=True)

    if 'Player-additional' in player_advanced.columns:
        player_advanced.rename(columns={'Player-additional': 'Player_ID'}, inplace=True)

    # FEATURE EXTRACTION
    curr_player_features = curr_player_gamelog[["PTS","Player_ID","Tm","Court","Opp"]]
    correct_abr = {"PHO":"PHX","CHO":"CHI","BRK":"BKN"}
    for index, row in curr_player_features.iterrows():
        if row["Opp"] in correct_abr:
            curr_player_features.at[index, "Opp"] = correct_abr[row["Opp"]]

    #switch the home vs away to binary - HOME = 1, AWAY = 0
    binary_court = {"home": 1, "away": 0}
    curr_player_features["Court"] = curr_player_features["Court"].map(binary_court)


    player_advanced_features = player_advanced[["Player_ID", "TS%", "FTr", "USG%", "BPM"]]
    player_basic_features = player_basic[["Player_ID", "PTS"]]
    

    team_advaced_features = team_advanced[["Team", "ORtg", "eFG%_2", "Pace"]]
    opponent_features = opponent_basic[["Team", "FG%"]]
    opponent_shooting_features = opponent_shooting[["Team", "Range_0-3", "Range_3-10"]]

    # COMBINE THE DATA FRAMES INTO A FINAL
    merged_df = pd.merge(curr_player_features, player_advanced_features, on="Player_ID", how="left")
    merged_df = pd.merge(merged_df, player_basic_features, on="Player_ID", how="left")
    merged_df.rename(columns = {"PTS_x" : "final_PTS"}, inplace = True)
    merged_df.rename(columns = {"PTS_y" : "avg_PTS"}, inplace = True)
    
    merged_df["ORtg"] = None
    merged_df["eFG%_2"] = None
    merged_df["Pace"] = None
    merged_df["Opponent_FG%"] = None
    merged_df["Range_0-3"] = None
    merged_df["Range_3-10"] = None

    for index, row in merged_df.iterrows():
        team_data = team_advaced_features[team_advaced_features["Team"] == row["Tm"]]
        if not team_data.empty:
            merged_df.at[index, "ORtg"] = team_data.iloc[0]["ORtg"]
            merged_df.at[index, "eFG%_2"] = team_data.iloc[0]["eFG%_2"]
            merged_df.at[index, "Pace"] = team_data.iloc[0]["Pace"]

        opp_data = opponent_features[opponent_features["Team"] == row["Opp"]]
        if not opp_data.empty:
            merged_df.at[index, "Opponent_FG%"] = opp_data.iloc[0]["FG%"]

       
        opp_shooting = opponent_shooting_features[opponent_shooting_features["Team"] == row["Opp"]]
        if not opp_shooting.empty:  
            merged_df.at[index, "Range_0-3"] = opp_shooting.iloc[0]["Range_0-3"]
            merged_df.at[index, "Range_3-10"] = opp_shooting.iloc[0]["Range_3-10"]
        
        team_data = team_advanced[team_advanced["Team"] == row["Tm"]]
    
    #Remove the non numerica columns now that all data has been organized
    #with_names = merged_df #if you want to see pre word removal
    #print(with_names)
    non_numeric_columns = ["Player_ID","Tm", "Opp", "Court"]
    merged_df = merged_df.drop(columns=non_numeric_columns)
    output_dir = r"C:\Github_Repos\MATH2015-Linear-Regression-Model\Linear Regression Data\Final Datasets"
    os.makedirs(output_dir, exist_ok=True)

    # Save the file
    merged_df.to_csv(os.path.join(output_dir, f"Final_Dataset_{player_id}.csv"), index=False)
    
    #print(opponent_shooting_features)
# Out:
# C:\Users\kings\AppData\Local\Temp\ipykernel_24292\2833653405.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curr_player_features["Court"] = curr_player_features["Court"].map(binary_court)

# %%
# File paths in correct order for final file creation
test_curr_player = r"C:\Github_Repos\MATH2015-Linear-Regression-Model\Linear Regression Data\Game Logs\brunsja01_gamelog_2023.xlsx"
player_basic_stats = r"C:\Github_Repos\MATH2015-Linear-Regression-Model\Linear Regression Data\23_24_Player_Basic_Stats.csv"
player_advanced_stats = r"C:\Github_Repos\MATH2015-Linear-Regression-Model\Linear Regression Data\23_24_Player_Advanced_Stats.csv"
team_basic_stats = r"C:\Github_Repos\MATH2015-Linear-Regression-Model\Linear Regression Data\23_24_Team_Basic_Stats.csv"
team_advanced_stats = r"C:\Github_Repos\MATH2015-Linear-Regression-Model\Linear Regression Data\23_24_Team_Advanced_Stats.csv"
opponent_basic_stats = r"C:\Github_Repos\MATH2015-Linear-Regression-Model\Linear Regression Data\23_24_Opponent_Basic_Stats.csv"
shooting_opponent_stats = r"C:\Github_Repos\MATH2015-Linear-Regression-Model\Linear Regression Data\23_24_Shooting_Opponent_Stats.csv"

# Call the function
final_file_creation(
    test_curr_player,
    player_basic_stats,
    player_advanced_stats,
    team_basic_stats,
    team_advanced_stats,
    opponent_basic_stats,
    shooting_opponent_stats
)
# Out:
# C:\Users\kings\AppData\Local\Temp\ipykernel_24292\1026421296.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curr_player_features["Court"] = curr_player_features["Court"].map(binary_court)

# %%
def scrape_list_names(players_path):
    player_data = pd.read_csv(players_path)
    filtered_players = player_data[player_data["MP"] > 8]
    player_list = filtered_players['Player-additional'].tolist()
    return player_list

# %% [markdown]
# # Run Scraper

# %%
ids = scrape_list_names(player_basic_stats) #get the IDs of all players who play over 8 minutes a game
ids_not_scraped = ids[33:] #so far I have 32 IDs

weird_names = []
error_names = []
year = 2023
#actual scraping, turn off for now

# for player_id in ids_not_scraped:
#         try:
#             curr_game_log = f"C:\\Github_Repos\\MATH2015-Linear-Regression-Model\\Linear Regression Data\\Game Logs\\{player_id}_gamelog_{year}.xlsx"
#             url = f'https://www.basketball-reference.com/players/{player_id[0]}/{player_id}/gamelog/{year}'
#             print(url)
#             scrape_gamelog(player_id, url, year)
#             time.sleep(random.uniform(5, 15))  # Wait for 2 seconds between request
#         except Exception as e:
#             # Capture any error that occurs and move to the next player
#             error_names.append((player_id, str(e)))
#             print(f"An error occurred with {player_id}: {e}")
# Out:
# https://www.basketball-reference.com/players/m/murrade01/gamelog/2023
# https://www.basketball-reference.com/players/t/thomaca02/gamelog/2023
# https://www.basketball-reference.com/players/k/kuzmaky01/gamelog/2023
# https://www.basketball-reference.com/players/t/townska01/gamelog/2023
# https://www.basketball-reference.com/players/s/siakapa01/gamelog/2023
# https://www.basketball-reference.com/players/s/siakapa01/gamelog/2023
# https://www.basketball-reference.com/players/s/siakapa01/gamelog/2023
# https://www.basketball-reference.com/players/w/wembavi01/gamelog/2023
# An error occurred with wembavi01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/m/murraja01/gamelog/2023
# https://www.basketball-reference.com/players/s/sengual01/gamelog/2023
# https://www.basketball-reference.com/players/b/bridgmi02/gamelog/2023
# An error occurred with bridgmi02: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/g/grantje01/gamelog/2023
# https://www.basketball-reference.com/players/b/butleji01/gamelog/2023
# https://www.basketball-reference.com/players/h/herroty01/gamelog/2023
# https://www.basketball-reference.com/players/i/ingrabr01/gamelog/2023
# https://www.basketball-reference.com/players/b/barrerj01/gamelog/2023
# https://www.basketball-reference.com/players/b/barrerj01/gamelog/2023
# https://www.basketball-reference.com/players/b/barrerj01/gamelog/2023
# https://www.basketball-reference.com/players/h/halibty01/gamelog/2023
# https://www.basketball-reference.com/players/p/porzikr01/gamelog/2023
# https://www.basketball-reference.com/players/m/mccolcj01/gamelog/2023
# https://www.basketball-reference.com/players/b/barnesc01/gamelog/2023
# https://www.basketball-reference.com/players/r/roziete01/gamelog/2023
# https://www.basketball-reference.com/players/r/roziete01/gamelog/2023
# https://www.basketball-reference.com/players/r/roziete01/gamelog/2023
# https://www.basketball-reference.com/players/w/wagnefr01/gamelog/2023
# https://www.basketball-reference.com/players/b/bridgmi01/gamelog/2023
# https://www.basketball-reference.com/players/g/greenja05/gamelog/2023
# https://www.basketball-reference.com/players/l/lavinza01/gamelog/2023
# https://www.basketball-reference.com/players/v/vassede01/gamelog/2023
# https://www.basketball-reference.com/players/s/sabondo01/gamelog/2023
# https://www.basketball-reference.com/players/a/adebaba01/gamelog/2023
# https://www.basketball-reference.com/players/w/whiteco01/gamelog/2023
# https://www.basketball-reference.com/players/w/willija06/gamelog/2023
# https://www.basketball-reference.com/players/s/sextoco01/gamelog/2023
# https://www.basketball-reference.com/players/b/bealbr01/gamelog/2023
# https://www.basketball-reference.com/players/g/garlada01/gamelog/2023
# https://www.basketball-reference.com/players/r/russeda01/gamelog/2023
# https://www.basketball-reference.com/players/v/vucevni01/gamelog/2023
# https://www.basketball-reference.com/players/t/thompkl01/gamelog/2023
# https://www.basketball-reference.com/players/p/poolejo01/gamelog/2023
# https://www.basketball-reference.com/players/v/vanvlfr01/gamelog/2023
# https://www.basketball-reference.com/players/m/millebr02/gamelog/2023
# An error occurred with millebr02: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/h/harrito02/gamelog/2023
# https://www.basketball-reference.com/players/c/clarkjo01/gamelog/2023
# https://www.basketball-reference.com/players/t/turnemy01/gamelog/2023
# https://www.basketball-reference.com/players/q/quickim01/gamelog/2023
# https://www.basketball-reference.com/players/q/quickim01/gamelog/2023
# https://www.basketball-reference.com/players/q/quickim01/gamelog/2023
# https://www.basketball-reference.com/players/b/bogdabo01/gamelog/2023
# https://www.basketball-reference.com/players/a/aytonde01/gamelog/2023
# https://www.basketball-reference.com/players/p/portemi01/gamelog/2023
# https://www.basketball-reference.com/players/h/hardeja01/gamelog/2023
# https://www.basketball-reference.com/players/a/allenja01/gamelog/2023
# https://www.basketball-reference.com/players/h/holmgch01/gamelog/2023
# An error occurred with holmgch01: 23 columns passed, passed data had 10 columns
# https://www.basketball-reference.com/players/k/kuminjo01/gamelog/2023
# https://www.basketball-reference.com/players/j/johnsja05/gamelog/2023
# https://www.basketball-reference.com/players/r/reaveau01/gamelog/2023
# https://www.basketball-reference.com/players/s/sharpsh01/gamelog/2023
# https://www.basketball-reference.com/players/b/brogdma01/gamelog/2023
# https://www.basketball-reference.com/players/j/johnske04/gamelog/2023
# https://www.basketball-reference.com/players/m/mobleev01/gamelog/2023
# https://www.basketball-reference.com/players/h/huntede01/gamelog/2023
# https://www.basketball-reference.com/players/d/divindo01/gamelog/2023
# https://www.basketball-reference.com/players/i/iveyja01/gamelog/2023
# https://www.basketball-reference.com/players/m/monkma01/gamelog/2023
# https://www.basketball-reference.com/players/o/oubreke01/gamelog/2023
# https://www.basketball-reference.com/players/b/bogdabo02/gamelog/2023
# https://www.basketball-reference.com/players/b/bogdabo02/gamelog/2023
# https://www.basketball-reference.com/players/b/bogdabo02/gamelog/2023
# https://www.basketball-reference.com/players/m/murrake02/gamelog/2023
# https://www.basketball-reference.com/players/w/whitede01/gamelog/2023
# https://www.basketball-reference.com/players/c/collijo01/gamelog/2023
# https://www.basketball-reference.com/players/m/middlkh01/gamelog/2023
# https://www.basketball-reference.com/players/m/murphtr02/gamelog/2023
# https://www.basketball-reference.com/players/a/anunoog01/gamelog/2023
# https://www.basketball-reference.com/players/a/anunoog01/gamelog/2023
# https://www.basketball-reference.com/players/a/anunoog01/gamelog/2023
# https://www.basketball-reference.com/players/a/avdijde01/gamelog/2023
# https://www.basketball-reference.com/players/j/jacksgg01/gamelog/2023
# An error occurred with jacksgg01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/m/mathube01/gamelog/2023
# https://www.basketball-reference.com/players/s/smartma01/gamelog/2023
# https://www.basketball-reference.com/players/h/hardati02/gamelog/2023
# https://www.basketball-reference.com/players/s/schrode01/gamelog/2023
# https://www.basketball-reference.com/players/s/schrode01/gamelog/2023
# https://www.basketball-reference.com/players/s/schrode01/gamelog/2023
# https://www.basketball-reference.com/players/g/goberru01/gamelog/2023
# https://www.basketball-reference.com/players/h/hendesc01/gamelog/2023
# An error occurred with hendesc01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/l/leverca01/gamelog/2023
# https://www.basketball-reference.com/players/g/gordoaa01/gamelog/2023
# https://www.basketball-reference.com/players/p/powelno01/gamelog/2023
# https://www.basketball-reference.com/players/d/durenja01/gamelog/2023
# https://www.basketball-reference.com/players/p/portibo01/gamelog/2023
# https://www.basketball-reference.com/players/b/beysa01/gamelog/2023
# https://www.basketball-reference.com/players/s/smithja05/gamelog/2023
# https://www.basketball-reference.com/players/t/trentga02/gamelog/2023
# https://www.basketball-reference.com/players/h/hachiru01/gamelog/2023
# https://www.basketball-reference.com/players/a/allengr01/gamelog/2023
# https://www.basketball-reference.com/players/r/reidna01/gamelog/2023
# https://www.basketball-reference.com/players/j/johnsca02/gamelog/2023
# https://www.basketball-reference.com/players/k/kispeco01/gamelog/2023
# https://www.basketball-reference.com/players/w/wiggian01/gamelog/2023
# https://www.basketball-reference.com/players/g/georgke01/gamelog/2023
# An error occurred with georgke01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/w/washipj01/gamelog/2023
# https://www.basketball-reference.com/players/w/washipj01/gamelog/2023
# https://www.basketball-reference.com/players/w/washipj01/gamelog/2023
# https://www.basketball-reference.com/players/p/pippesc02/gamelog/2023
# https://www.basketball-reference.com/players/r/robindu01/gamelog/2023
# https://www.basketball-reference.com/players/b/brookdi01/gamelog/2023
# https://www.basketball-reference.com/players/w/willima07/gamelog/2023
# https://www.basketball-reference.com/players/s/suggsja01/gamelog/2023
# https://www.basketball-reference.com/players/h/holidjr01/gamelog/2023
# https://www.basketball-reference.com/players/l/lopezbr01/gamelog/2023
# https://www.basketball-reference.com/players/g/giddejo01/gamelog/2023
# https://www.basketball-reference.com/players/w/whitmca01/gamelog/2023
# An error occurred with whitmca01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/b/barneha02/gamelog/2023
# https://www.basketball-reference.com/players/d/dosunay01/gamelog/2023
# https://www.basketball-reference.com/players/g/greenja02/gamelog/2023
# https://www.basketball-reference.com/players/n/nesmiaa01/gamelog/2023
# https://www.basketball-reference.com/players/s/strusma01/gamelog/2023
# https://www.basketball-reference.com/players/v/valanjo01/gamelog/2023
# https://www.basketball-reference.com/players/h/hieldbu01/gamelog/2023
# https://www.basketball-reference.com/players/h/hieldbu01/gamelog/2023
# https://www.basketball-reference.com/players/h/hieldbu01/gamelog/2023
# https://www.basketball-reference.com/players/j/jonesty01/gamelog/2023
# https://www.basketball-reference.com/players/j/jaqueja01/gamelog/2023
# An error occurred with jaqueja01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/c/claxtni01/gamelog/2023
# https://www.basketball-reference.com/players/b/baglema01/gamelog/2023
# https://www.basketball-reference.com/players/b/baglema01/gamelog/2023
# https://www.basketball-reference.com/players/b/baglema01/gamelog/2023
# https://www.basketball-reference.com/players/z/zubaciv01/gamelog/2023
# https://www.basketball-reference.com/players/a/anthoco01/gamelog/2023
# https://www.basketball-reference.com/players/s/sochaje01/gamelog/2023
# https://www.basketball-reference.com/players/c/capelca01/gamelog/2023
# https://www.basketball-reference.com/players/c/conlemi01/gamelog/2023
# https://www.basketball-reference.com/players/b/beaslma01/gamelog/2023
# https://www.basketball-reference.com/players/c/clarkbr01/gamelog/2023
# https://www.basketball-reference.com/players/c/colliza01/gamelog/2023
# https://www.basketball-reference.com/players/m/meltode01/gamelog/2023
# https://www.basketball-reference.com/players/p/poeltja01/gamelog/2023
# https://www.basketball-reference.com/players/w/westbru01/gamelog/2023
# https://www.basketball-reference.com/players/g/gaffoda01/gamelog/2023
# https://www.basketball-reference.com/players/g/gaffoda01/gamelog/2023
# https://www.basketball-reference.com/players/g/gaffoda01/gamelog/2023
# https://www.basketball-reference.com/players/c/cartewe01/gamelog/2023
# https://www.basketball-reference.com/players/g/gordoer01/gamelog/2023
# https://www.basketball-reference.com/players/j/joneshe01/gamelog/2023
# https://www.basketball-reference.com/players/k/kennalu01/gamelog/2023
# https://www.basketball-reference.com/players/d/dortlu01/gamelog/2023
# https://www.basketball-reference.com/players/n/nurkiju01/gamelog/2023
# https://www.basketball-reference.com/players/s/stewais01/gamelog/2023
# https://www.basketball-reference.com/players/w/wagnemo01/gamelog/2023
# https://www.basketball-reference.com/players/b/brownbr01/gamelog/2023
# https://www.basketball-reference.com/players/b/brownbr01/gamelog/2023
# https://www.basketball-reference.com/players/b/brownbr01/gamelog/2023
# https://www.basketball-reference.com/players/l/laravja01/gamelog/2023
# https://www.basketball-reference.com/players/a/aldamsa01/gamelog/2023
# https://www.basketball-reference.com/players/f/fontesi01/gamelog/2023
# https://www.basketball-reference.com/players/f/fontesi01/gamelog/2023
# https://www.basketball-reference.com/players/f/fontesi01/gamelog/2023
# https://www.basketball-reference.com/players/d/dinwisp01/gamelog/2023
# https://www.basketball-reference.com/players/d/dinwisp01/gamelog/2023
# https://www.basketball-reference.com/players/d/dinwisp01/gamelog/2023
# https://www.basketball-reference.com/players/m/mcdanja02/gamelog/2023
# https://www.basketball-reference.com/players/b/burksal01/gamelog/2023
# https://www.basketball-reference.com/players/b/burksal01/gamelog/2023
# https://www.basketball-reference.com/players/b/burksal01/gamelog/2023
# https://www.basketball-reference.com/players/b/bantoda01/gamelog/2023
# https://www.basketball-reference.com/players/b/bantoda01/gamelog/2023
# https://www.basketball-reference.com/players/w/willigr01/gamelog/2023
# https://www.basketball-reference.com/players/w/willigr01/gamelog/2023
# https://www.basketball-reference.com/players/w/willigr01/gamelog/2023
# https://www.basketball-reference.com/players/t/toppiob01/gamelog/2023
# https://www.basketball-reference.com/players/h/huertke01/gamelog/2023
# https://www.basketball-reference.com/players/j/jacksre01/gamelog/2023
# https://www.basketball-reference.com/players/m/mccontj01/gamelog/2023
# https://www.basketball-reference.com/players/o/okongon01/gamelog/2023
# https://www.basketball-reference.com/players/c/caldwke01/gamelog/2023
# https://www.basketball-reference.com/players/c/carusal01/gamelog/2023
# https://www.basketball-reference.com/players/h/hortota01/gamelog/2023
# https://www.basketball-reference.com/players/j/jonestr01/gamelog/2023
# https://www.basketball-reference.com/players/m/martica02/gamelog/2023
# https://www.basketball-reference.com/players/w/willipa01/gamelog/2023
# https://www.basketball-reference.com/players/w/willivi01/gamelog/2023
# https://www.basketball-reference.com/players/r/richajo01/gamelog/2023
# https://www.basketball-reference.com/players/s/smithja04/gamelog/2023
# https://www.basketball-reference.com/players/h/haywago01/gamelog/2023
# https://www.basketball-reference.com/players/h/haywago01/gamelog/2023
# https://www.basketball-reference.com/players/h/haywago01/gamelog/2023
# https://www.basketball-reference.com/players/o/olynyke01/gamelog/2023
# https://www.basketball-reference.com/players/o/olynyke01/gamelog/2023
# https://www.basketball-reference.com/players/o/olynyke01/gamelog/2023
# https://www.basketball-reference.com/players/e/easonta01/gamelog/2023
# https://www.basketball-reference.com/players/r/richani01/gamelog/2023
# https://www.basketball-reference.com/players/w/walkelo01/gamelog/2023
# https://www.basketball-reference.com/players/p/pritcpa01/gamelog/2023
# https://www.basketball-reference.com/players/t/thompam01/gamelog/2023
# An error occurred with thompam01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/h/hartjo01/gamelog/2023
# https://www.basketball-reference.com/players/n/niangge01/gamelog/2023
# https://www.basketball-reference.com/players/o/okorois01/gamelog/2023
# https://www.basketball-reference.com/players/m/manntr01/gamelog/2023
# https://www.basketball-reference.com/players/m/manntr01/gamelog/2023
# https://www.basketball-reference.com/players/m/manntr01/gamelog/2023
# https://www.basketball-reference.com/players/b/branhma01/gamelog/2023
# https://www.basketball-reference.com/players/n/nembhan01/gamelog/2023
# https://www.basketball-reference.com/players/p/paulch01/gamelog/2023
# https://www.basketball-reference.com/players/p/podzibr01/gamelog/2023
# An error occurred with podzibr01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/r/reathdu01/gamelog/2023
# An error occurred with reathdu01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/h/hausesa01/gamelog/2023
# https://www.basketball-reference.com/players/p/princta02/gamelog/2023
# https://www.basketball-reference.com/players/w/walkeja01/gamelog/2023
# https://www.basketball-reference.com/players/l/livelde01/gamelog/2023
# An error occurred with livelde01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/l/loveke01/gamelog/2023
# https://www.basketball-reference.com/players/m/mannte01/gamelog/2023
# https://www.basketball-reference.com/players/t/thompau01/gamelog/2023
# An error occurred with thompau01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/g/greendr01/gamelog/2023
# https://www.basketball-reference.com/players/h/horfoal01/gamelog/2023
# https://www.basketball-reference.com/players/j/jonesde02/gamelog/2023
# https://www.basketball-reference.com/players/d/dickgr01/gamelog/2023
# An error occurred with dickgr01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/f/finnedo01/gamelog/2023
# https://www.basketball-reference.com/players/v/vukcetr01/gamelog/2023
# An error occurred with vukcetr01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/c/coulibi01/gamelog/2023
# An error occurred with coulibi01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/d/drumman01/gamelog/2023
# https://www.basketball-reference.com/players/m/mcbrimi01/gamelog/2023
# https://www.basketball-reference.com/players/s/sassema01/gamelog/2023
# An error occurred with sassema01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/g/greenjo02/gamelog/2023
# https://www.basketball-reference.com/players/j/joeis01/gamelog/2023
# https://www.basketball-reference.com/players/w/willizi02/gamelog/2023
# https://www.basketball-reference.com/players/l/lowryky01/gamelog/2023
# https://www.basketball-reference.com/players/l/lowryky01/gamelog/2023
# https://www.basketball-reference.com/players/l/lowryky01/gamelog/2023
# https://www.basketball-reference.com/players/k/kesslwa01/gamelog/2023
# https://www.basketball-reference.com/players/m/moodymo01/gamelog/2023
# https://www.basketball-reference.com/players/a/alexani01/gamelog/2023
# https://www.basketball-reference.com/players/m/merrisa01/gamelog/2023
# https://www.basketball-reference.com/players/r/rosede01/gamelog/2023
# https://www.basketball-reference.com/players/s/saricda01/gamelog/2023
# https://www.basketball-reference.com/players/j/jackstr02/gamelog/2023
# An error occurred with jackstr02: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/e/exumda01/gamelog/2023
# An error occurred with exumda01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/f/fultzma01/gamelog/2023
# https://www.basketball-reference.com/players/h/harteis01/gamelog/2023
# https://www.basketball-reference.com/players/h/hawkijo01/gamelog/2023
# An error occurred with hawkijo01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/o/onealro01/gamelog/2023
# https://www.basketball-reference.com/players/o/onealro01/gamelog/2023
# https://www.basketball-reference.com/players/o/onealro01/gamelog/2023
# https://www.basketball-reference.com/players/g/grayra01/gamelog/2023
# https://www.basketball-reference.com/players/j/jovicni01/gamelog/2023
# https://www.basketball-reference.com/players/a/achiupr01/gamelog/2023
# https://www.basketball-reference.com/players/a/achiupr01/gamelog/2023
# https://www.basketball-reference.com/players/a/achiupr01/gamelog/2023
# https://www.basketball-reference.com/players/c/camarto01/gamelog/2023
# An error occurred with camarto01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/m/martico01/gamelog/2023
# https://www.basketball-reference.com/players/s/sensabr01/gamelog/2023
# An error occurred with sensabr01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/p/payneca01/gamelog/2023
# https://www.basketball-reference.com/players/p/payneca01/gamelog/2023
# https://www.basketball-reference.com/players/p/payneca01/gamelog/2023
# https://www.basketball-reference.com/players/b/braunch01/gamelog/2023
# https://www.basketball-reference.com/players/h/hardyja02/gamelog/2023
# https://www.basketball-reference.com/players/h/hendrita0/gamelog/2023
# An error occurred with hendrita0: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/r/reedpa01/gamelog/2023
# https://www.basketball-reference.com/players/s/stevela01/gamelog/2023
# https://www.basketball-reference.com/players/s/stevela01/gamelog/2023
# https://www.basketball-reference.com/players/j/juzanjo01/gamelog/2023
# https://www.basketball-reference.com/players/k/knoxke01/gamelog/2023
# https://www.basketball-reference.com/players/l/lylestr01/gamelog/2023
# https://www.basketball-reference.com/players/a/alvarjo01/gamelog/2023
# https://www.basketball-reference.com/players/m/marshna01/gamelog/2023
# https://www.basketball-reference.com/players/s/shamela01/gamelog/2023
# https://www.basketball-reference.com/players/w/wisemja01/gamelog/2023
# https://www.basketball-reference.com/players/m/micicva01/gamelog/2023
# An error occurred with micicva01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/m/micicva01/gamelog/2023
# An error occurred with micicva01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/m/micicva01/gamelog/2023
# An error occurred with micicva01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/n/nworajo01/gamelog/2023
# https://www.basketball-reference.com/players/n/nworajo01/gamelog/2023
# https://www.basketball-reference.com/players/n/nworajo01/gamelog/2023
# https://www.basketball-reference.com/players/g/grimequ01/gamelog/2023
# https://www.basketball-reference.com/players/g/grimequ01/gamelog/2023
# https://www.basketball-reference.com/players/g/grimequ01/gamelog/2023
# https://www.basketball-reference.com/players/f/freemja01/gamelog/2023
# An error occurred with freemja01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/f/fournev01/gamelog/2023
# https://www.basketball-reference.com/players/f/fournev01/gamelog/2023
# https://www.basketball-reference.com/players/f/fournev01/gamelog/2023
# https://www.basketball-reference.com/players/h/harriga01/gamelog/2023
# https://www.basketball-reference.com/players/h/hayeski01/gamelog/2023
# https://www.basketball-reference.com/players/h/hylanbo01/gamelog/2023
# https://www.basketball-reference.com/players/p/pereima01/gamelog/2023
# An error occurred with pereima01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/w/watfotr01/gamelog/2023
# https://www.basketball-reference.com/players/w/wiggiaa01/gamelog/2023
# https://www.basketball-reference.com/players/w/woodch01/gamelog/2023
# https://www.basketball-reference.com/players/j/jemistr01/gamelog/2023
# An error occurred with jemistr01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/j/jemistr01/gamelog/2023
# An error occurred with jemistr01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/c/champju02/gamelog/2023
# https://www.basketball-reference.com/players/i/isaacjo01/gamelog/2023
# https://www.basketball-reference.com/players/o/osmande01/gamelog/2023
# https://www.basketball-reference.com/players/s/sharpda01/gamelog/2023
# https://www.basketball-reference.com/players/w/wallaca01/gamelog/2023
# An error occurred with wallaca01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/w/williro04/gamelog/2023
# https://www.basketball-reference.com/players/b/bertada01/gamelog/2023
# https://www.basketball-reference.com/players/b/bertada01/gamelog/2023
# https://www.basketball-reference.com/players/r/ramseja01/gamelog/2023
# An error occurred with ramseja01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/w/watsope01/gamelog/2023
# https://www.basketball-reference.com/players/c/coffeam01/gamelog/2023
# https://www.basketball-reference.com/players/h/holidaa01/gamelog/2023
# https://www.basketball-reference.com/players/s/smithde03/gamelog/2023
# https://www.basketball-reference.com/players/m/metuch01/gamelog/2023
# https://www.basketball-reference.com/players/m/metuch01/gamelog/2023
# https://www.basketball-reference.com/players/m/metuch01/gamelog/2023
# https://www.basketball-reference.com/players/g/goodwjo01/gamelog/2023
# https://www.basketball-reference.com/players/g/goodwjo01/gamelog/2023
# https://www.basketball-reference.com/players/g/goodwjo01/gamelog/2023
# https://www.basketball-reference.com/players/r/roddyda01/gamelog/2023
# https://www.basketball-reference.com/players/r/roddyda01/gamelog/2023
# https://www.basketball-reference.com/players/d/dukeda01/gamelog/2023
# https://www.basketball-reference.com/players/g/greenje02/gamelog/2023
# https://www.basketball-reference.com/players/j/jacksis01/gamelog/2023
# https://www.basketball-reference.com/players/m/morrima03/gamelog/2023
# https://www.basketball-reference.com/players/m/morrima03/gamelog/2023
# https://www.basketball-reference.com/players/m/morrima03/gamelog/2023
# https://www.basketball-reference.com/players/a/anderky01/gamelog/2023
# https://www.basketball-reference.com/players/b/bouchch01/gamelog/2023
# https://www.basketball-reference.com/players/b/butleja02/gamelog/2023
# https://www.basketball-reference.com/players/f/fernabr01/gamelog/2023
# https://www.basketball-reference.com/players/t/theisda01/gamelog/2023
# https://www.basketball-reference.com/players/t/theisda01/gamelog/2023
# https://www.basketball-reference.com/players/n/nowelja01/gamelog/2023
# https://www.basketball-reference.com/players/n/nowelja01/gamelog/2023
# https://www.basketball-reference.com/players/n/nowelja01/gamelog/2023
# https://www.basketball-reference.com/players/b/beverpa01/gamelog/2023
# https://www.basketball-reference.com/players/b/beverpa01/gamelog/2023
# https://www.basketball-reference.com/players/b/beverpa01/gamelog/2023
# https://www.basketball-reference.com/players/c/crowdja01/gamelog/2023
# https://www.basketball-reference.com/players/j/johnske07/gamelog/2023
# https://www.basketball-reference.com/players/h/highsha01/gamelog/2023
# https://www.basketball-reference.com/players/k/krejcvi01/gamelog/2023
# https://www.basketball-reference.com/players/m/murrakr01/gamelog/2023
# An error occurred with murrakr01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/s/simmobe01/gamelog/2023
# https://www.basketball-reference.com/players/s/simpsza01/gamelog/2023
# An error occurred with simpsza01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/e/evbuoto01/gamelog/2023
# An error occurred with evbuoto01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/e/evbuoto01/gamelog/2023
# An error occurred with evbuoto01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/e/evbuoto01/gamelog/2023
# An error occurred with evbuoto01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/c/champju01/gamelog/2023
# https://www.basketball-reference.com/players/s/smithni01/gamelog/2023
# An error occurred with smithni01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/a/agbajoc01/gamelog/2023
# https://www.basketball-reference.com/players/a/agbajoc01/gamelog/2023
# https://www.basketball-reference.com/players/a/agbajoc01/gamelog/2023
# https://www.basketball-reference.com/players/c/clownno01/gamelog/2023
# An error occurred with clownno01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/d/daniedy01/gamelog/2023
# https://www.basketball-reference.com/players/g/gallida01/gamelog/2023
# An error occurred with gallida01: 23 columns passed, passed data had 10 columns
# https://www.basketball-reference.com/players/g/gallida01/gamelog/2023
# An error occurred with gallida01: 23 columns passed, passed data had 10 columns
# https://www.basketball-reference.com/players/g/gallida01/gamelog/2023
# An error occurred with gallida01: 23 columns passed, passed data had 10 columns
# https://www.basketball-reference.com/players/g/gallida01/gamelog/2023
# An error occurred with gallida01: 23 columns passed, passed data had 10 columns
# https://www.basketball-reference.com/players/b/bryanth01/gamelog/2023
# https://www.basketball-reference.com/players/c/craigto01/gamelog/2023
# https://www.basketball-reference.com/players/n/nancela02/gamelog/2023
# https://www.basketball-reference.com/players/c/connapa01/gamelog/2023
# https://www.basketball-reference.com/players/p/portecr01/gamelog/2023
# An error occurred with portecr01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/r/robinmi01/gamelog/2023
# https://www.basketball-reference.com/players/f/flynnma01/gamelog/2023
# https://www.basketball-reference.com/players/f/flynnma01/gamelog/2023
# https://www.basketball-reference.com/players/f/flynnma01/gamelog/2023
# https://www.basketball-reference.com/players/m/mcderdo01/gamelog/2023
# https://www.basketball-reference.com/players/m/mcderdo01/gamelog/2023
# https://www.basketball-reference.com/players/m/mcderdo01/gamelog/2023
# https://www.basketball-reference.com/players/p/paytoga02/gamelog/2023
# https://www.basketball-reference.com/players/q/quetane01/gamelog/2023
# https://www.basketball-reference.com/players/c/councri01/gamelog/2023
# An error occurred with councri01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/d/dunnkr01/gamelog/2023
# https://www.basketball-reference.com/players/e/elliske01/gamelog/2023
# https://www.basketball-reference.com/players/r/reddica01/gamelog/2023
# https://www.basketball-reference.com/players/r/ryanma01/gamelog/2023
# https://www.basketball-reference.com/players/t/thybuma01/gamelog/2023
# https://www.basketball-reference.com/players/v/vezenal01/gamelog/2023
# An error occurred with vezenal01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/w/wadede01/gamelog/2023
# https://www.basketball-reference.com/players/b/bazleda01/gamelog/2023
# https://www.basketball-reference.com/players/b/bazleda01/gamelog/2023
# https://www.basketball-reference.com/players/t/tillmxa01/gamelog/2023
# https://www.basketball-reference.com/players/t/tillmxa01/gamelog/2023
# https://www.basketball-reference.com/players/t/tillmxa01/gamelog/2023
# https://www.basketball-reference.com/players/b/batumni01/gamelog/2023
# https://www.basketball-reference.com/players/b/batumni01/gamelog/2023
# https://www.basketball-reference.com/players/b/batumni01/gamelog/2023
# https://www.basketball-reference.com/players/k/kornelu01/gamelog/2023
# https://www.basketball-reference.com/players/m/mitchda01/gamelog/2023
# https://www.basketball-reference.com/players/p/plumlma01/gamelog/2023
# https://www.basketball-reference.com/players/u/umudest01/gamelog/2023
# https://www.basketball-reference.com/players/p/pokusal01/gamelog/2023
# https://www.basketball-reference.com/players/p/pokusal01/gamelog/2023
# https://www.basketball-reference.com/players/b/bolbo01/gamelog/2023
# https://www.basketball-reference.com/players/b/bostobr01/gamelog/2023
# https://www.basketball-reference.com/players/v/vandeja01/gamelog/2023
# https://www.basketball-reference.com/players/c/curryse01/gamelog/2023
# https://www.basketball-reference.com/players/c/curryse01/gamelog/2023
# https://www.basketball-reference.com/players/c/curryse01/gamelog/2023
# https://www.basketball-reference.com/players/e/eubandr01/gamelog/2023
# https://www.basketball-reference.com/players/m/mcgowbr01/gamelog/2023
# https://www.basketball-reference.com/players/h/holmeri01/gamelog/2023
# https://www.basketball-reference.com/players/h/holmeri01/gamelog/2023
# https://www.basketball-reference.com/players/h/holmeri01/gamelog/2023
# https://www.basketball-reference.com/players/m/morrimo01/gamelog/2023
# https://www.basketball-reference.com/players/m/morrimo01/gamelog/2023
# https://www.basketball-reference.com/players/m/morrimo01/gamelog/2023
# https://www.basketball-reference.com/players/b/bitadgo01/gamelog/2023
# https://www.basketball-reference.com/players/c/carteje01/gamelog/2023
# https://www.basketball-reference.com/players/g/grahade01/gamelog/2023
# https://www.basketball-reference.com/players/l/liveris01/gamelog/2023
# https://www.basketball-reference.com/players/s/simmoko01/gamelog/2023
# https://www.basketball-reference.com/players/w/wilsoja03/gamelog/2023
# An error occurred with wilsoja03: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/l/landajo01/gamelog/2023
# https://www.basketball-reference.com/players/m/mathega01/gamelog/2023
# https://www.basketball-reference.com/players/r/rhodeja01/gamelog/2023
# https://www.basketball-reference.com/players/b/bufkiko01/gamelog/2023
# An error occurred with bufkiko01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/j/jarrede01/gamelog/2023
# An error occurred with jarrede01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/o/omorueu01/gamelog/2023
# https://www.basketball-reference.com/players/w/willike04/gamelog/2023
# https://www.basketball-reference.com/players/l/loftoke01/gamelog/2023
# https://www.basketball-reference.com/players/l/loftoke01/gamelog/2023
# https://www.basketball-reference.com/players/b/blackan01/gamelog/2023
# An error occurred with blackan01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/o/okogijo01/gamelog/2023
# https://www.basketball-reference.com/players/y/yurtsom01/gamelog/2023
# https://www.basketball-reference.com/players/m/miltosh01/gamelog/2023
# https://www.basketball-reference.com/players/m/miltosh01/gamelog/2023
# https://www.basketball-reference.com/players/m/miltosh01/gamelog/2023
# https://www.basketball-reference.com/players/w/wrighde01/gamelog/2023
# https://www.basketball-reference.com/players/w/wrighde01/gamelog/2023
# https://www.basketball-reference.com/players/w/wrighde01/gamelog/2023
# https://www.basketball-reference.com/players/g/greenaj01/gamelog/2023
# https://www.basketball-reference.com/players/l/looneke01/gamelog/2023
# https://www.basketball-reference.com/players/m/mooreta02/gamelog/2023
# An error occurred with mooreta02: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/s/strawju01/gamelog/2023
# An error occurred with strawju01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/b/biyombi01/gamelog/2023
# https://www.basketball-reference.com/players/b/biyombi01/gamelog/2023
# https://www.basketball-reference.com/players/c/covinro01/gamelog/2023
# https://www.basketball-reference.com/players/c/covinro01/gamelog/2023
# https://www.basketball-reference.com/players/c/covinro01/gamelog/2023
# https://www.basketball-reference.com/players/b/baldwpa01/gamelog/2023
# https://www.basketball-reference.com/players/b/bambamo01/gamelog/2023
# https://www.basketball-reference.com/players/b/barlodo01/gamelog/2023
# https://www.basketball-reference.com/players/b/beaucma01/gamelog/2023
# https://www.basketball-reference.com/players/i/inglejo01/gamelog/2023
# https://www.basketball-reference.com/players/k/klebima01/gamelog/2023
# https://www.basketball-reference.com/players/p/portejo01/gamelog/2023
# An error occurred with portejo01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/q/quinole01/gamelog/2023
# https://www.basketball-reference.com/players/s/sheppbe01/gamelog/2023
# An error occurred with sheppbe01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/w/weslebl01/gamelog/2023
# https://www.basketball-reference.com/players/d/dowtije01/gamelog/2023
# https://www.basketball-reference.com/players/h/hayesja02/gamelog/2023
# https://www.basketball-reference.com/players/h/houstca01/gamelog/2023
# An error occurred with houstca01: HTTPSConnectionPool(host='www.basketball-reference.com', port=443): Max retries exceeded with url: /players/h/houstca01/gamelog/2023 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002577DE94210>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# https://www.basketball-reference.com/players/k/konchjo01/gamelog/2023
# https://www.basketball-reference.com/players/s/smithdr01/gamelog/2023
# https://www.basketball-reference.com/players/y/youngth01/gamelog/2023
# https://www.basketball-reference.com/players/y/youngth01/gamelog/2023
# https://www.basketball-reference.com/players/y/youngth01/gamelog/2023
# https://www.basketball-reference.com/players/g/gilyaja01/gamelog/2023
# https://www.basketball-reference.com/players/g/gilyaja01/gamelog/2023
# https://www.basketball-reference.com/players/g/gilyaja01/gamelog/2023
# https://www.basketball-reference.com/players/b/brookar01/gamelog/2023
# An error occurred with brookar01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/b/browntr01/gamelog/2023
# https://www.basketball-reference.com/players/b/browntr01/gamelog/2023
# https://www.basketball-reference.com/players/b/browntr01/gamelog/2023
# https://www.basketball-reference.com/players/c/chrisma02/gamelog/2023
# https://www.basketball-reference.com/players/h/haganas01/gamelog/2023
# An error occurred with haganas01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/h/houseda01/gamelog/2023
# https://www.basketball-reference.com/players/m/mayssk01/gamelog/2023
# https://www.basketball-reference.com/players/m/mayssk01/gamelog/2023
# https://www.basketball-reference.com/players/m/mamuksa01/gamelog/2023
# https://www.basketball-reference.com/players/s/samanlu01/gamelog/2023
# https://www.basketball-reference.com/players/t/tateja01/gamelog/2023
# https://www.basketball-reference.com/players/m/millspa02/gamelog/2023
# https://www.basketball-reference.com/players/m/millspa02/gamelog/2023
# https://www.basketball-reference.com/players/m/millspa02/gamelog/2023
# https://www.basketball-reference.com/players/d/diengou01/gamelog/2023
# https://www.basketball-reference.com/players/g/gueyemo02/gamelog/2023
# An error occurred with gueyemo02: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/h/holidju01/gamelog/2023
# https://www.basketball-reference.com/players/h/hurtma01/gamelog/2023
# An error occurred with hurtma01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/m/mykhasv01/gamelog/2023
# https://www.basketball-reference.com/players/r/ruperra01/gamelog/2023
# An error occurred with ruperra01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/w/willija07/gamelog/2023
# https://www.basketball-reference.com/players/d/duartch01/gamelog/2023
# https://www.basketball-reference.com/players/j/jordade01/gamelog/2023
# https://www.basketball-reference.com/players/c/cissosi01/gamelog/2023
# An error occurred with cissosi01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/g/gillan01/gamelog/2023
# https://www.basketball-reference.com/players/m/martike04/gamelog/2023
# https://www.basketball-reference.com/players/m/martike04/gamelog/2023
# https://www.basketball-reference.com/players/m/martike04/gamelog/2023
# https://www.basketball-reference.com/players/b/bateske01/gamelog/2023
# https://www.basketball-reference.com/players/b/bateske01/gamelog/2023
# https://www.basketball-reference.com/players/b/brissos01/gamelog/2023
# https://www.basketball-reference.com/players/c/cainja01/gamelog/2023
# https://www.basketball-reference.com/players/w/warretj01/gamelog/2023
# https://www.basketball-reference.com/players/g/gilleco01/gamelog/2023
# An error occurred with gilleco01: 23 columns passed, passed data had 10 columns
# https://www.basketball-reference.com/players/s/santogu01/gamelog/2023
# An error occurred with santogu01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/w/walkeja02/gamelog/2023
# An error occurred with walkeja02: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/m/maledth01/gamelog/2023
# https://www.basketball-reference.com/players/m/maledth01/gamelog/2023
# https://www.basketball-reference.com/players/b/bitimon01/gamelog/2023
# An error occurred with bitimon01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/m/mclaujo01/gamelog/2023
# https://www.basketball-reference.com/players/b/boldema01/gamelog/2023
# An error occurred with boldema01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/b/boldema01/gamelog/2023
# An error occurred with boldema01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/w/watanyu01/gamelog/2023
# https://www.basketball-reference.com/players/w/watanyu01/gamelog/2023
# https://www.basketball-reference.com/players/w/watanyu01/gamelog/2023
# https://www.basketball-reference.com/players/b/boehebu01/gamelog/2023
# https://www.basketball-reference.com/players/b/brownmo01/gamelog/2023
# https://www.basketball-reference.com/players/g/gabriwe01/gamelog/2023
# https://www.basketball-reference.com/players/l/littlna01/gamelog/2023
# https://www.basketball-reference.com/players/m/mcdanja01/gamelog/2023
# https://www.basketball-reference.com/players/s/sprinja01/gamelog/2023
# https://www.basketball-reference.com/players/s/sprinja01/gamelog/2023
# https://www.basketball-reference.com/players/b/bassech01/gamelog/2023
# https://www.basketball-reference.com/players/p/pottemi01/gamelog/2023
# https://www.basketball-reference.com/players/p/poweldw01/gamelog/2023
# https://www.basketball-reference.com/players/t/templga01/gamelog/2023
# https://www.basketball-reference.com/players/t/thomptr01/gamelog/2023
# An error occurred with thomptr01: 31 columns passed, passed data had 10 columns
# https://www.basketball-reference.com/players/l/lewiski01/gamelog/2023
# https://www.basketball-reference.com/players/l/lewiski01/gamelog/2023
# https://www.basketball-reference.com/players/l/lewiski01/gamelog/2023
# https://www.basketball-reference.com/players/n/nnajize01/gamelog/2023
# https://www.basketball-reference.com/players/s/smithis01/gamelog/2023
# https://www.basketball-reference.com/players/t/thorjt01/gamelog/2023
# https://www.basketball-reference.com/players/m/matthwe02/gamelog/2023
# https://www.basketball-reference.com/players/t/terryda01/gamelog/2023
# https://www.basketball-reference.com/players/v/vincega01/gamelog/2023
# https://www.basketball-reference.com/players/m/muscami01/gamelog/2023
# https://www.basketball-reference.com/players/m/muscami01/gamelog/2023
# https://www.basketball-reference.com/players/m/muscami01/gamelog/2023
# https://www.basketball-reference.com/players/d/davisjo06/gamelog/2023
# https://www.basketball-reference.com/players/p/prospol01/gamelog/2023
# An error occurred with prospol01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/q/queentr01/gamelog/2023
# https://www.basketball-reference.com/players/r/robinje02/gamelog/2023
# https://www.basketball-reference.com/players/c/cartodj01/gamelog/2023
# An error occurred with cartodj01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/r/robinor01/gamelog/2023
# https://www.basketball-reference.com/players/b/batesem01/gamelog/2023
# An error occurred with batesem01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/b/blackle01/gamelog/2023
# An error occurred with blackle01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/w/willima11/gamelog/2023
# An error occurred with willima11: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/a/allenti01/gamelog/2023
# An error occurred with allenti01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/p/porteot01/gamelog/2023
# https://www.basketball-reference.com/players/f/fudgeal01/gamelog/2023
# An error occurred with fudgeal01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/w/windldy01/gamelog/2023
# https://www.basketball-reference.com/players/k/korkmfu01/gamelog/2023
# https://www.basketball-reference.com/players/l/lenal01/gamelog/2023
# https://www.basketball-reference.com/players/m/morrima02/gamelog/2023
# https://www.basketball-reference.com/players/g/griffaj01/gamelog/2023
# https://www.basketball-reference.com/players/g/gueyemo01/gamelog/2023
# An error occurred with gueyemo01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/h/harrijo01/gamelog/2023
# https://www.basketball-reference.com/players/j/josepco01/gamelog/2023
# https://www.basketball-reference.com/players/m/moonxa01/gamelog/2023
# https://www.basketball-reference.com/players/b/bouyeja01/gamelog/2023
# https://www.basketball-reference.com/players/b/bouyeja01/gamelog/2023
# https://www.basketball-reference.com/players/b/bouyeja01/gamelog/2023
# https://www.basketball-reference.com/players/o/okekech01/gamelog/2023
# https://www.basketball-reference.com/players/s/seabrde01/gamelog/2023
# https://www.basketball-reference.com/players/b/bullore01/gamelog/2023
# https://www.basketball-reference.com/players/f/forretr01/gamelog/2023
# https://www.basketball-reference.com/players/j/jacksan01/gamelog/2023
# An error occurred with jacksan01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/p/phillju01/gamelog/2023
# An error occurred with phillju01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/b/brownko01/gamelog/2023
# An error occurred with brownko01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/s/simsje01/gamelog/2023
# https://www.basketball-reference.com/players/m/minayju01/gamelog/2023
# https://www.basketball-reference.com/players/g/gibsota01/gamelog/2023
# https://www.basketball-reference.com/players/g/gibsota01/gamelog/2023
# https://www.basketball-reference.com/players/g/gibsota01/gamelog/2023
# https://www.basketball-reference.com/players/t/tuckepj01/gamelog/2023
# https://www.basketball-reference.com/players/t/tuckepj01/gamelog/2023
# https://www.basketball-reference.com/players/t/tuckepj01/gamelog/2023
# https://www.basketball-reference.com/players/p/prestja01/gamelog/2023
# https://www.basketball-reference.com/players/w/walshjo01/gamelog/2023
# An error occurred with walshjo01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/b/badjiib01/gamelog/2023
# An error occurred with badjiib01: 23 columns passed, passed data had 10 columns
# https://www.basketball-reference.com/players/w/whiteda01/gamelog/2023
# An error occurred with whiteda01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/w/whiteja03/gamelog/2023
# https://www.basketball-reference.com/players/h/hamptrj01/gamelog/2023
# https://www.basketball-reference.com/players/m/mensana01/gamelog/2023
# An error occurred with mensana01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/n/ntilila01/gamelog/2023
# https://www.basketball-reference.com/players/g/greenda02/gamelog/2023
