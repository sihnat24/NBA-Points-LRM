# %%
import pandas as pd
import os
import time
import random
import requests
from bs4 import BeautifulSoup
import pyautogui
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.

# %%
# README: NBA Player Data Filter Code

# Overview
# This code defines the `scrape_list_names` function, which processes NBA player data from a CSV file.
# It 

def scrape_list_names(players_path):
    """
    Extracts a list of player names from a CSV file based on a filter condition.

    Args:
        players_path (str): The file path to the CSV file containing player data.
                           The CSV must include the following columns:
                           - 'MP': Minutes played by the player.
                           - 'Player-additional': Column containing player names.

    Output:
        list: A Python list of player names (from the 'Player-additional' column) 
              who average more than 8 minutes per game.
    """
    player_data = pd.read_csv(players_path)
    filtered_players = player_data[player_data["MP"] > 8]
    player_list = filtered_players['Player-additional'].tolist()
    return player_list

# %%
def scrape_gamelog(player_id, url, year):
    """
    Scrapes NBA player game log data from Basketball Reference and saves it as a CSV file.

    Args:
        player_id (str): The unique identifier for the player.
        url (str): The URL of the player's Basketball Reference game log page.
        year (int): The season year for which the game log data is being retrieved.

    Output:
        - Saves a CSV file containing the player's game log data in the specified directory.
        - The file is named as '{player_id}_gamelog_{year}.csv'.

    Returns:
        None
    """
    
    #Go to website and open basketball reference page
    response = requests.get(url)

    # Check for response status
    if response.status_code != 200:
        print(f"Failed to retrieve data for {player_id}. Status code: {response.status_code}")
        return None  # Exit function early
    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.find('table', {'id': 'pgl_basic'})
    headers = [th.text for th in table.find('thead').find_all('th')][1:]
    rows = table.find('tbody').find_all('tr')
    data = []
    # Pull the data from the table
    for row in rows:
        if row.find('th', {'scope': 'row'}) is not None:
            game_date = row.find('th').text
            cells = row.find_all('td')
            cells_data = [cell.text for cell in cells]
            data.append([player_id, game_date] + cells_data)
    headers = ['Player_ID', 'Date'] + headers
    df = pd.DataFrame(data, columns=headers)
    # Remove rows where the player did not play (G column is empty)
    df = df[df['G'] != '']
    # Modify the 7th column based on its content
    df.iloc[:, 6] = df.iloc[:, 6].apply(lambda x: 'away' if '@' in x else 'home')
    # Rename columns
    df.rename(columns={df.columns[8]: 'Court'}, inplace=True)
    # Remove the second column
    df.drop(df.columns[1], axis=1, inplace=True)
    # Define the directory where you want to save the file
     
    save_directory = f"C:\Github_Repos\MATH2015-Linear-Regression-Model\Linear_Regression_Data\Game Logs\Game_Logs_{year}"
    # Ensure the directory exists
    os.makedirs(save_directory, exist_ok=True)
    # Create the full file path
    file_name = os.path.join(save_directory, f'{player_id}_gamelog_{year}.xlsx')
    # Save to Excel with player ID in the file name
    with pd.ExcelWriter(file_name) as writer:
        df.to_excel(writer, index=False, sheet_name='Game Log')

# %%
#CSV with player averages from entire season
player_basic_stats = r"C:\Github_Repos\MATH2015-Linear-Regression-Model\Linear_Regression_Data\2020_Averages\20_21_Player_Basic_Stats.csv"
ids = scrape_list_names(player_basic_stats) #get the IDs of all players who play over 8 minutes a game
error_names = [] #capture any names that caused errors
year = 2020
#actual scraping, turn off for 

for player_id in ids:
        try:
            curr_game_log = f"C:\\Github_Repos\\MATH2015-Linear-Regression-Model\\Linear_Regression_Data\\Game_Logs\\{player_id}_gamelog_{year}.xlsx"
            url = f'https://www.basketball-reference.com/players/{player_id[0]}/{player_id}/gamelog/{year}'
            print(url)
            scrape_gamelog(player_id, url, year)
            pyautogui.moveRel(0, 1)
            pyautogui.moveRel(0, -1)
            time.sleep(random.uniform(5, 15))  # Wait for 2 seconds between request
        except Exception as e:
            # Capture any error that occurs and move to the next player
            error_names.append((player_id, str(e)))
            print(f"An error occurred with {player_id}: {e}")
# Out:
# https://www.basketball-reference.com/players/c/curryst01/gamelog/2020
# https://www.basketball-reference.com/players/b/bealbr01/gamelog/2020
# https://www.basketball-reference.com/players/l/lillada01/gamelog/2020
# https://www.basketball-reference.com/players/e/embiijo01/gamelog/2020
# https://www.basketball-reference.com/players/a/antetgi01/gamelog/2020
# https://www.basketball-reference.com/players/d/doncilu01/gamelog/2020
# https://www.basketball-reference.com/players/l/lavinza01/gamelog/2020
# https://www.basketball-reference.com/players/w/willizi01/gamelog/2020
# https://www.basketball-reference.com/players/d/duranke01/gamelog/2020
# An error occurred with duranke01: 23 columns passed, passed data had 10 columns
# https://www.basketball-reference.com/players/i/irvinky01/gamelog/2020
# https://www.basketball-reference.com/players/j/jokicni01/gamelog/2020
# https://www.basketball-reference.com/players/m/mitchdo01/gamelog/2020
# https://www.basketball-reference.com/players/t/tatumja01/gamelog/2020
# https://www.basketball-reference.com/players/b/bookede01/gamelog/2020
# https://www.basketball-reference.com/players/y/youngtr01/gamelog/2020
# https://www.basketball-reference.com/players/f/foxde01/gamelog/2020
# https://www.basketball-reference.com/players/j/jamesle01/gamelog/2020
# https://www.basketball-reference.com/players/l/leonaka01/gamelog/2020
# https://www.basketball-reference.com/players/t/townska01/gamelog/2020
# https://www.basketball-reference.com/players/b/brownja02/gamelog/2020
# https://www.basketball-reference.com/players/h/hardeja01/gamelog/2020
# https://www.basketball-reference.com/players/h/hardeja01/gamelog/2020
# https://www.basketball-reference.com/players/h/hardeja01/gamelog/2020
# https://www.basketball-reference.com/players/s/sextoco01/gamelog/2020
# https://www.basketball-reference.com/players/r/randlju01/gamelog/2020
# https://www.basketball-reference.com/players/i/ingrabr01/gamelog/2020
# https://www.basketball-reference.com/players/g/gilgesh01/gamelog/2020
# https://www.basketball-reference.com/players/v/vucevni01/gamelog/2020
# https://www.basketball-reference.com/players/v/vucevni01/gamelog/2020
# https://www.basketball-reference.com/players/v/vucevni01/gamelog/2020
# https://www.basketball-reference.com/players/g/georgpa01/gamelog/2020
# https://www.basketball-reference.com/players/m/mccolcj01/gamelog/2020
# https://www.basketball-reference.com/players/g/grantje01/gamelog/2020
# https://www.basketball-reference.com/players/w/westbru01/gamelog/2020
# https://www.basketball-reference.com/players/d/davisan02/gamelog/2020
# https://www.basketball-reference.com/players/d/derozde01/gamelog/2020
# https://www.basketball-reference.com/players/b/butleji01/gamelog/2020
# https://www.basketball-reference.com/players/s/siakapa01/gamelog/2020
# https://www.basketball-reference.com/players/b/brogdma01/gamelog/2020
# https://www.basketball-reference.com/players/m/murraja01/gamelog/2020
# https://www.basketball-reference.com/players/w/woodch01/gamelog/2020
# https://www.basketball-reference.com/players/w/walljo01/gamelog/2020
# An error occurred with walljo01: 23 columns passed, passed data had 10 columns
# https://www.basketball-reference.com/players/m/middlkh01/gamelog/2020
# https://www.basketball-reference.com/players/r/roziete01/gamelog/2020
# https://www.basketball-reference.com/players/s/sabondo01/gamelog/2020
# https://www.basketball-reference.com/players/l/leverca01/gamelog/2020
# https://www.basketball-reference.com/players/l/leverca01/gamelog/2020
# https://www.basketball-reference.com/players/l/leverca01/gamelog/2020
# https://www.basketball-reference.com/players/p/porzikr01/gamelog/2020
# https://www.basketball-reference.com/players/o/oladivi01/gamelog/2020
# https://www.basketball-reference.com/players/o/oladivi01/gamelog/2020
# https://www.basketball-reference.com/players/o/oladivi01/gamelog/2020
# https://www.basketball-reference.com/players/o/oladivi01/gamelog/2020
# https://www.basketball-reference.com/players/b/beaslma01/gamelog/2020
# https://www.basketball-reference.com/players/h/haywago01/gamelog/2020
# https://www.basketball-reference.com/players/v/vanvlfr01/gamelog/2020
# https://www.basketball-reference.com/players/h/harrito02/gamelog/2020
# https://www.basketball-reference.com/players/e/edwaran01/gamelog/2020
# An error occurred with edwaran01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/w/walkeke02/gamelog/2020
# https://www.basketball-reference.com/players/m/moranja01/gamelog/2020
# https://www.basketball-reference.com/players/p/portemi01/gamelog/2020
# https://www.basketball-reference.com/players/r/russeda01/gamelog/2020
# https://www.basketball-reference.com/players/a/adebaba01/gamelog/2020
# https://www.basketball-reference.com/players/p/powelno01/gamelog/2020
# https://www.basketball-reference.com/players/p/powelno01/gamelog/2020
# https://www.basketball-reference.com/players/p/powelno01/gamelog/2020
# https://www.basketball-reference.com/players/w/wiggian01/gamelog/2020
# https://www.basketball-reference.com/players/c/clarkjo01/gamelog/2020
# https://www.basketball-reference.com/players/g/gordoer01/gamelog/2020
# https://www.basketball-reference.com/players/h/holidjr01/gamelog/2020
# https://www.basketball-reference.com/players/b/barrerj01/gamelog/2020
# https://www.basketball-reference.com/players/c/collijo01/gamelog/2020
# https://www.basketball-reference.com/players/g/garlada01/gamelog/2020
# https://www.basketball-reference.com/players/b/brookdi01/gamelog/2020
# https://www.basketball-reference.com/players/l/lowryky01/gamelog/2020
# https://www.basketball-reference.com/players/f/fournev01/gamelog/2020
# https://www.basketball-reference.com/players/f/fournev01/gamelog/2020
# https://www.basketball-reference.com/players/f/fournev01/gamelog/2020
# https://www.basketball-reference.com/players/v/valanjo01/gamelog/2020
# https://www.basketball-reference.com/players/b/bogdabo02/gamelog/2020
# https://www.basketball-reference.com/players/h/hardati02/gamelog/2020
# https://www.basketball-reference.com/players/h/hieldbu01/gamelog/2020
# https://www.basketball-reference.com/players/p/porteke02/gamelog/2020
# https://www.basketball-reference.com/players/b/bogdabo01/gamelog/2020
# https://www.basketball-reference.com/players/p/paulch01/gamelog/2020
# https://www.basketball-reference.com/players/t/thomakh01/gamelog/2020
# https://www.basketball-reference.com/players/c/conlemi01/gamelog/2020
# https://www.basketball-reference.com/players/b/barneha02/gamelog/2020
# https://www.basketball-reference.com/players/b/bryanel01/gamelog/2020
# An error occurred with bryanel01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/a/anunoog01/gamelog/2020
# https://www.basketball-reference.com/players/b/ballla01/gamelog/2020
# An error occurred with ballla01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/m/murrade01/gamelog/2020
# https://www.basketball-reference.com/players/r/rosste01/gamelog/2020
# https://www.basketball-reference.com/players/w/warretj01/gamelog/2020
# https://www.basketball-reference.com/players/o/oubreke01/gamelog/2020
# https://www.basketball-reference.com/players/s/schrode01/gamelog/2020
# https://www.basketball-reference.com/players/w/whitede01/gamelog/2020
# https://www.basketball-reference.com/players/t/trentga02/gamelog/2020
# https://www.basketball-reference.com/players/t/trentga02/gamelog/2020
# https://www.basketball-reference.com/players/t/trentga02/gamelog/2020
# https://www.basketball-reference.com/players/c/capelca01/gamelog/2020
# https://www.basketball-reference.com/players/h/herroty01/gamelog/2020
# https://www.basketball-reference.com/players/w/whiteco01/gamelog/2020
# https://www.basketball-reference.com/players/h/huntede01/gamelog/2020
# https://www.basketball-reference.com/players/d/drumman01/gamelog/2020
# https://www.basketball-reference.com/players/d/drumman01/gamelog/2020
# https://www.basketball-reference.com/players/d/drumman01/gamelog/2020
# https://www.basketball-reference.com/players/g/grahade01/gamelog/2020
# https://www.basketball-reference.com/players/r/rosede01/gamelog/2020
# https://www.basketball-reference.com/players/r/rosede01/gamelog/2020
# https://www.basketball-reference.com/players/r/rosede01/gamelog/2020
# https://www.basketball-reference.com/players/b/balllo01/gamelog/2020
# https://www.basketball-reference.com/players/n/nunnke01/gamelog/2020
# https://www.basketball-reference.com/players/a/aytonde01/gamelog/2020
# https://www.basketball-reference.com/players/j/jacksja02/gamelog/2020
# https://www.basketball-reference.com/players/b/bryanth01/gamelog/2020
# https://www.basketball-reference.com/players/g/goberru01/gamelog/2020
# https://www.basketball-reference.com/players/s/simmobe01/gamelog/2020
# https://www.basketball-reference.com/players/h/holmeri01/gamelog/2020
# https://www.basketball-reference.com/players/h/horfoal01/gamelog/2020
# https://www.basketball-reference.com/players/b/baglema01/gamelog/2020
# https://www.basketball-reference.com/players/h/harrijo01/gamelog/2020
# https://www.basketball-reference.com/players/d/dortlu01/gamelog/2020
# https://www.basketball-reference.com/players/h/hachiru01/gamelog/2020
# https://www.basketball-reference.com/players/b/bazleda01/gamelog/2020
# https://www.basketball-reference.com/players/b/bouchch01/gamelog/2020
# https://www.basketball-reference.com/players/m/markkla01/gamelog/2020
# https://www.basketball-reference.com/players/m/mcderdo01/gamelog/2020
# https://www.basketball-reference.com/players/o/olynyke01/gamelog/2020
# https://www.basketball-reference.com/players/o/olynyke01/gamelog/2020
# https://www.basketball-reference.com/players/o/olynyke01/gamelog/2020
# https://www.basketball-reference.com/players/a/aldrila01/gamelog/2020
# https://www.basketball-reference.com/players/a/aldrila01/gamelog/2020
# https://www.basketball-reference.com/players/a/aldrila01/gamelog/2020
# https://www.basketball-reference.com/players/b/bridgmi01/gamelog/2020
# https://www.basketball-reference.com/players/h/harremo01/gamelog/2020
# https://www.basketball-reference.com/players/a/anthoca01/gamelog/2020
# https://www.basketball-reference.com/players/d/dragigo01/gamelog/2020
# https://www.basketball-reference.com/players/j/jacksjo02/gamelog/2020
# https://www.basketball-reference.com/players/m/morrima03/gamelog/2020
# https://www.basketball-reference.com/players/g/gallida01/gamelog/2020
# https://www.basketball-reference.com/players/r/robindu01/gamelog/2020
# https://www.basketball-reference.com/players/s/smartma01/gamelog/2020
# https://www.basketball-reference.com/players/h/halibty01/gamelog/2020
# An error occurred with halibty01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/m/miltosh01/gamelog/2020
# https://www.basketball-reference.com/players/a/anthoco01/gamelog/2020
# An error occurred with anthoco01: 'NoneType' object has no attribute 'find'
# https://www.basketball-reference.com/players/f/fultzma01/gamelog/2020
# https://www.basketball-reference.com/players/k/kuzmaky01/gamelog/2020
# https://www.basketball-reference.com/players/w/washipj01/gamelog/2020
# https://www.basketball-reference.com/players/a/allenja01/gamelog/2020
# https://www.basketball-reference.com/players/a/allenja01/gamelog/2020
# https://www.basketball-reference.com/players/a/allenja01/gamelog/2020
# https://www.basketball-reference.com/players/j/johnske04/gamelog/2020
# https://www.basketball-reference.com/players/b/bartowi01/gamelog/2020
# https://www.basketball-reference.com/players/b/bridgmi02/gamelog/2020
# https://www.basketball-reference.com/players/b/burksal01/gamelog/2020
# https://www.basketball-reference.com/players/b/brunsja01/gamelog/2020
# https://www.basketball-reference.com/players/t/turnemy01/gamelog/2020
# https://www.basketball-reference.com/players/c/curryse01/gamelog/2020
# https://www.basketball-reference.com/players/g/gordoaa01/gamelog/2020
# https://www.basketball-reference.com/players/g/gordoaa01/gamelog/2020
# https://www.basketball-reference.com/players/g/gordoaa01/gamelog/2020
# https://www.basketball-reference.com/players/a/anderky01/gamelog/2020
# https://www.basketball-reference.com/players/l/lopezbr01/gamelog/2020
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 14
#      12     print(url)
#      13     scrape_gamelog(player_id, url, year)
# ---> 14     time.sleep(random.uniform(5, 15))  # Wait for 2 seconds between request
#      15 except Exception as e:
#      16     # Capture any error that occurs and move to the next player
#      17     error_names.append((player_id, str(e)))
#
# KeyboardInterrupt:
